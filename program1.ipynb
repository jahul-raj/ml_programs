# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv("housing.csv")
numerical=df.select_dtypes(include='number')
numerical
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
# [20640 rows x 9 columns]

# %%
for col in numerical:
    plt.figure(figsize=(10,8))
    sns.histplot(df[col])
    plt.show()
    plt.figure(figsize=(10,8))
    sns.boxplot(df[col])
    plt.show()

# %%
for col in numerical:
    q1=df[col].quantile(0.25)
    q3=df[col].quantile(0.75)
    iqr=q3-q1
    lower_bound=q1-1.5*iqr
    upper_bound=q3+1.5*iqr
    outlier=df[(df[col]<lower_bound)|(df[col]>upper_bound)]
    print("Lower bound :",upper_bound)
    print("Upper bound :",lower_bound)
    print(col,":",len(outlier))
# Out:
# Lower bound : -112.32500000000002
# Upper bound : -127.48499999999999
# longitude : 0
# Lower bound : 43.38
# Upper bound : 28.259999999999998
# latitude : 0
# Lower bound : 65.5
# Upper bound : -10.5
# housing_median_age : 0
# Lower bound : 5698.375
# Upper bound : -1102.625
# total_rooms : 1287
# Lower bound : 1173.5
# Upper bound : -230.5
# total_bedrooms : 1271
# Lower bound : 3132.0
# Upper bound : -620.0
# population : 1196
# Lower bound : 1092.5
# Upper bound : -207.5
# households : 1220
# Lower bound : 8.013024999999999
# Upper bound : -0.7063750000000004
# median_income : 681
# Lower bound : 482412.5
# Upper bound : -98087.5
# median_house_value : 1071
