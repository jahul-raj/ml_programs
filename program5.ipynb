# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

values=np.random.rand(100)
values
# Out:
# array([0.19279627, 0.26021161, 0.12227876, 0.23922613, 0.54261194,
#        0.79559666, 0.53574987, 0.95011853, 0.69028069, 0.03115451,
#        0.74794734, 0.81927406, 0.14155185, 0.67865653, 0.62787721,
#        0.07106738, 0.28376043, 0.04793323, 0.55069312, 0.71965982,
#        0.83355314, 0.51632561, 0.28094561, 0.84310209, 0.98492144,
#        0.74820427, 0.6807809 , 0.32630693, 0.39540044, 0.27876864,
#        0.99355289, 0.49629757, 0.56512872, 0.37586639, 0.26434844,
#        0.44458328, 0.81176264, 0.69840818, 0.60908576, 0.88346911,
#        0.47078144, 0.82387642, 0.55502646, 0.55397497, 0.63137343,
#        0.20030468, 0.20578828, 0.98147639, 0.81236669, 0.67029355,
#        0.54091883, 0.65860734, 0.6525106 , 0.4711383 , 0.99566028,
#        0.4782875 , 0.94686004, 0.81740952, 0.55437415, 0.07419739,
#        0.50655746, 0.49557188, 0.57401652, 0.27631562, 0.12932498,
#        0.01909376, 0.9602132 , 0.44430234, 0.18407987, 0.17792293,
# ...

# %%
labels=[]
for col in values[:50]:
    if col<0.5:
        labels.append('class1')
    else:
        labels.append('class2')
labels +=[None]*50
print(labels)
# Out:
# ['class1', 'class1', 'class1', 'class1', 'class2', 'class2', 'class2', 'class2', 'class2', 'class1', 'class2', 'class2', 'class1', 'class2', 'class2', 'class1', 'class1', 'class1', 'class2', 'class2', 'class2', 'class2', 'class1', 'class2', 'class2', 'class2', 'class2', 'class1', 'class1', 'class1', 'class2', 'class1', 'class2', 'class1', 'class1', 'class1', 'class2', 'class2', 'class2', 'class2', 'class1', 'class2', 'class2', 'class2', 'class2', 'class1', 'class1', 'class2', 'class2', 'class2', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
data={'Points':[f"x{i+1}" for i in range(100)],
'Values':values,
      'Labels':labels}
df=pd.DataFrame(data)
df
# Out:
#    Points    Values  Labels
# 0      x1  0.192796  class1
# 1      x2  0.260212  class1
# 2      x3  0.122279  class1
# 3      x4  0.239226  class1
# 4      x5  0.542612  class2
# ..    ...       ...     ...
# 95    x96  0.752697    None
# 96    x97  0.107388    None
# 97    x98  0.527918    None
# 98    x99  0.764009    None
# 99   x100  0.967069    None
#
# [100 rows x 3 columns]

# %%
labeled_df=df[df["Labels"].notna()]
x_train=labeled_df[["Values"]]
y_train=labeled_df[["Labels"]]
unlabeled_df=df[df["Labels"].isna()]
x_test=unlabeled_df[["Values"]]
true_labeled=["class1" if x<=0.5 else "class2" for x in values[50:]]
# Out:
#    Points    Values  Labels
# 0      x1  0.192796  class1
# 1      x2  0.260212  class1
# 2      x3  0.122279  class1
# 3      x4  0.239226  class1
# 4      x5  0.542612  class2
# 5      x6  0.795597  class2
# 6      x7  0.535750  class2
# 7      x8  0.950119  class2
# 8      x9  0.690281  class2
# 9     x10  0.031155  class1
# 10    x11  0.747947  class2
# 11    x12  0.819274  class2
# 12    x13  0.141552  class1
# 13    x14  0.678657  class2
# 14    x15  0.627877  class2
# 15    x16  0.071067  class1
# 16    x17  0.283760  class1
# 17    x18  0.047933  class1
# 18    x19  0.550693  class2
# 19    x20  0.719660  class2
# 20    x21  0.833553  class2
# 21    x22  0.516326  class2
# 22    x23  0.280946  class1
# 23    x24  0.843102  class2
# 24    x25  0.984921  class2
# 25    x26  0.748204  class2
# 26    x27  0.680781  class2
# 27    x28  0.326307  class1
# 28    x29  0.395400  class1
# 29    x30  0.278769  class1
# 30    x31  0.993553  class2
# 31    x32  0.496298  class1
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
kvalues=[1,2,3,4,5,20,30]
for i in kvalues:
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    prediction=knn.predict(x_test)
    print(f"Accuracy for k={i}")
    print(classification_report(true_labeled,prediction))
# Out:
# Accuracy for k=1
#               precision    recall  f1-score   support
#
#       class1       1.00      1.00      1.00        26
#       class2       1.00      1.00      1.00        24
#
#     accuracy                           1.00        50
#    macro avg       1.00      1.00      1.00        50
# weighted avg       1.00      1.00      1.00        50
#
# Accuracy for k=2
#               precision    recall  f1-score   support
#
#       class1       0.96      1.00      0.98        26
#       class2       1.00      0.96      0.98        24
#
#     accuracy                           0.98        50
#    macro avg       0.98      0.98      0.98        50
# weighted avg       0.98      0.98      0.98        50
#
# Accuracy for k=3
#               precision    recall  f1-score   support
#
#       class1       1.00      1.00      1.00        26
#       class2       1.00      1.00      1.00        24
#
#     accuracy                           1.00        50
# ...
